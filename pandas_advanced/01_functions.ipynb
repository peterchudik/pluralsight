# %%
import pandas as pd
# Out:
# C:\Users\Pepo\AppData\Local\Temp\ipykernel_16016\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Merge

# %%
df1 = pd.DataFrame({"ID": [1, 2, 3], "Name": ["Alice", "Bob", "Charlie"]})
df2 = pd.DataFrame({"ID": [2, 3, 4], "Name": ["NotBob", "Charlie", "Tom"], "Age": [25, 30, 35]})

print(df1)
print("-------------------")
print(df2)
# Out:
#    ID     Name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# -------------------
#    ID     Name  Age
# 0   2   NotBob   25
# 1   3  Charlie   30
# 2   4      Tom   35

# %%
# Merge on 1 column
merged_df = pd.merge(df1, df2[["ID", "Age"]], how="inner", on="ID")

merged_df
# Out:
#    ID     Name  Age
# 0   2      Bob   25
# 1   3  Charlie   30

# %%
# Merge on multiple column
merged_df = pd.merge(df1, df2, how="inner", on=["ID", "Name"])

merged_df
# Out:
#    ID     Name  Age
# 0   3  Charlie   30

# %%
# Merge on indexes
merged_df = pd.merge(df1, df2, left_index=True, right_index=True, how="inner", suffixes=("_left", "_right"))

merged_df
# Out:
#    ID_left Name_left  ID_right Name_right  Age
# 0        1     Alice         2     NotBob   25
# 1        2       Bob         3    Charlie   30
# 2        3   Charlie         4        Tom   35

# %% [markdown]
# # Join

# %%
df1 = pd.DataFrame({"ID": [1, 2, 3], "Name": ["Alice", "Bob", "Charlie"]}, index=[1, 2, 3])
df2 = pd.DataFrame({"ID": [2, 3, 3, 4], "Name": ["NotBob", "Charlie", "Charlie", "Tom"], "Age": [25, 30, 30, 35]}, index=[2, 3, 3, 4])

print(df1)
print("-------------------")
print(df2)
# Out:
#    ID     Name
# 1   1    Alice
# 2   2      Bob
# 3   3  Charlie
# -------------------
#    ID     Name  Age
# 2   2   NotBob   25
# 3   3  Charlie   30
# 3   3  Charlie   30
# 4   4      Tom   35

# %%
# inner on indexes
df_joined = df1.join(df2, how="inner", lsuffix="_left", rsuffix="_right")

df_joined
# Out:
#    ID_left Name_left  ID_right Name_right  Age
# 2        2       Bob         2     NotBob   25
# 3        3   Charlie         3    Charlie   30
# 3        3   Charlie         3    Charlie   30

# %%
# outer on indexes
df_joined = df1.join(df2, how="outer", lsuffix="_left", rsuffix="_right")

df_joined
# Out:
#    ID_left Name_left  ID_right Name_right   Age
# 1      1.0     Alice       NaN        NaN   NaN
# 2      2.0       Bob       2.0     NotBob  25.0
# 3      3.0   Charlie       3.0    Charlie  30.0
# 3      3.0   Charlie       3.0    Charlie  30.0
# 4      NaN       NaN       4.0        Tom  35.0

# %%
# left on indexes
df_joined = df1.join(df2, how="left", lsuffix="_left", rsuffix="_right")

df_joined
# Out:
#    ID_left Name_left  ID_right Name_right   Age
# 1        1     Alice       NaN        NaN   NaN
# 2        2       Bob       2.0     NotBob  25.0
# 3        3   Charlie       3.0    Charlie  30.0
# 3        3   Charlie       3.0    Charlie  30.0

# %%
# right on indexes
df_joined = df1.join(df2, how="right", lsuffix="_left", rsuffix="_right")

df_joined
# Out:
#    ID_left Name_left  ID_right Name_right  Age
# 2      2.0       Bob         2     NotBob   25
# 3      3.0   Charlie         3    Charlie   30
# 3      3.0   Charlie         3    Charlie   30
# 4      NaN       NaN         4        Tom   35

# %%
# inner on indexes with validation, raises error

df_joined = pd.DataFrame()

try:
    df_joined = df1.join(df2, how="inner", lsuffix="_left", rsuffix="_right", validate="one_to_one")
except pd.errors.MergeError :
    print("Not a 1:1 join")

df_joined
# Out:
# Not a 1:1 join
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Concat

# %%
df1 = pd.DataFrame({"ID": [1, 2, 3], "Name": ["Alice", "Bob", "Charlie"], "City": ["Zurich", "Basel", "Zurich"]}, index=[1, 2, 3])
df2 = pd.DataFrame({"ID": [2, 3, 3, 4], "Name": ["NotBob", "Charlie", "Charlie", "Tom"], "Age": [25, 30, 30, 35]}, index=[1, 2, 3, 4])

print(df1)
print("-------------------")
print(df2)
# Out:
#    ID     Name    City
# 1   1    Alice  Zurich
# 2   2      Bob   Basel
# 3   3  Charlie  Zurich
# -------------------
#    ID     Name  Age
# 1   2   NotBob   25
# 2   3  Charlie   30
# 3   3  Charlie   30
# 4   4      Tom   35

# %%
df_concat = pd.concat([df1, df2])

df_concat
# Out:
#    ID     Name    City   Age
# 1   1    Alice  Zurich   NaN
# 2   2      Bob   Basel   NaN
# 3   3  Charlie  Zurich   NaN
# 2   2   NotBob     NaN  25.0
# 3   3  Charlie     NaN  30.0
# 3   3  Charlie     NaN  30.0
# 4   4      Tom     NaN  35.0

# %%
df_concat = pd.concat([df1, df2], join="inner")

df_concat
# Out:
#    ID     Name
# 1   1    Alice
# 2   2      Bob
# 3   3  Charlie
# 1   2   NotBob
# 2   3  Charlie
# 3   3  Charlie
# 4   4      Tom

# %%
df_concat = pd.concat([df1, df2], ignore_index=True)

df_concat
# Out:
#    ID     Name    City   Age
# 0   1    Alice  Zurich   NaN
# 1   2      Bob   Basel   NaN
# 2   3  Charlie  Zurich   NaN
# 3   2   NotBob     NaN  25.0
# 4   3  Charlie     NaN  30.0
# 5   3  Charlie     NaN  30.0
# 6   4      Tom     NaN  35.0

# %%
df_concat = pd.concat([df1, df2], keys=["df1", "df2"])

df_concat
# Out:
#        ID     Name    City   Age
# df1 1   1    Alice  Zurich   NaN
#     2   2      Bob   Basel   NaN
#     3   3  Charlie  Zurich   NaN
# df2 1   2   NotBob     NaN  25.0
#     2   3  Charlie     NaN  30.0
#     3   3  Charlie     NaN  30.0
#     4   4      Tom     NaN  35.0

# %%
df_concat = pd.concat([df1, df2], axis=1)

df_concat
# Out:
#      0        1       2  3        4   5
# 1  1.0    Alice  Zurich  2   NotBob  25
# 2  2.0      Bob   Basel  3  Charlie  30
# 3  3.0  Charlie  Zurich  3  Charlie  30
# 4  NaN      NaN     NaN  4      Tom  35

# %% [markdown]
# # Cut function

# %%
ages = [10, 15, 20, 24, 26, 30, 31, 35, 40, 46, 50, 55, 60, 70, 100]

bin_edges = [20, 40, 60, 80]

# %%
age_groups = pd.cut(ages, bins=bin_edges, labels=["20-40", "40-60", "60-80"])

df = pd.DataFrame({"Age": ages, "Age_group": age_groups})

df
# Out:
#     Age Age_group
# 0    10       NaN
# 1    15       NaN
# 2    20       NaN
# 3    24     20-40
# 4    26     20-40
# 5    30     20-40
# 6    31     20-40
# 7    35     20-40
# 8    40     20-40
# 9    46     40-60
# 10   50     40-60
# 11   55     40-60
# 12   60     40-60
# 13   70     60-80
# 14  100       NaN

# %%
age_groups = pd.cut(ages, bins=bin_edges, labels=["20-40", "40-60", "60-80"], include_lowest=True)

df = pd.DataFrame({"Age": ages, "Age_group": age_groups})

df
# Out:
#     Age Age_group
# 0    10       NaN
# 1    15       NaN
# 2    20     20-40
# 3    24     20-40
# 4    26     20-40
# 5    30     20-40
# 6    31     20-40
# 7    35     20-40
# 8    40     20-40
# 9    46     40-60
# 10   50     40-60
# 11   55     40-60
# 12   60     40-60
# 13   70     60-80
# 14  100       NaN

# %%
age_groups = pd.cut(ages, bins=bin_edges, labels=["20-40", "40-60", "60-80"], include_lowest=True, right=False)

df = pd.DataFrame({"Age": ages, "Age_group": age_groups})

df
# Out:
#     Age Age_group
# 0    10       NaN
# 1    15       NaN
# 2    20     20-40
# 3    24     20-40
# 4    26     20-40
# 5    30     20-40
# 6    31     20-40
# 7    35     20-40
# 8    40     40-60
# 9    46     40-60
# 10   50     40-60
# 11   55     40-60
# 12   60     60-80
# 13   70     60-80
# 14  100       NaN

# %% [markdown]
# # QCut function

# %%
scores = [65, 72, 78, 80, 85, 90, 95, 98, 99]

quaniles = [0, 0.33, 0.66, 1]

labels=["Low", "Medium", "High"]

# %%
performance_categories = pd.qcut(scores, q=quaniles, labels=labels)

df = pd.DataFrame({"Scores": scores, "Performance_category": performance_categories})

df
# Out:
#    Scores Performance_category
# 0      65                  Low
# 1      72                  Low
# 2      78                  Low
# 3      80               Medium
# 4      85               Medium
# 5      90               Medium
# 6      95                 High
# 7      98                 High
# 8      99                 High

# %% [markdown]
# # Pivot

# %%
data = {
    "Date": ["2024-01-01","2024-01-01","2024-01-02","2024-01-02"],
    "Product": ["A", "B", "A", "B"],
    "Amount": [100, 150, 120, 180]
}

df = pd.DataFrame(data)

df
# Out:
#          Date Product  Amount
# 0  2024-01-01       A     100
# 1  2024-01-01       B     150
# 2  2024-01-02       A     120
# 3  2024-01-02       B     180

# %%
df_pivot = df.pivot(index="Date", columns="Product", values="Amount")

df_pivot
# Out:
# Product       A    B
# Date
# 2024-01-01  100  150
# 2024-01-02  120  180

# %%
df_pivot.columns
# Out:
# Index(['A', 'B'], dtype='object', name='Product')

# %%
df_pivot.index
# Out:
# Index(['2024-01-01', '2024-01-02'], dtype='object', name='Date')

# %% [markdown]
# # Melt

# %%
data = {
    "Participant": ["Alice", "Bob", "Charlie"],
    "Q1": [4, 5, 3],
    "Q2": [5, 3, 4],
    "Q3": [3, 4, 5],
}

df = pd.DataFrame(data)

df
# Out:
#   Participant  Q1  Q2  Q3
# 0       Alice   4   5   3
# 1         Bob   5   3   4
# 2     Charlie   3   4   5

# %%
df_melt = pd.melt(df, id_vars="Participant", value_vars=["Q1", "Q2", "Q3"], var_name= "Question", value_name="Response")

df_melt
# Out:
#   Participant Question  Response
# 0       Alice       Q1         4
# 1         Bob       Q1         5
# 2     Charlie       Q1         3
# 3       Alice       Q2         5
# 4         Bob       Q2         3
# 5     Charlie       Q2         4
# 6       Alice       Q3         3
# 7         Bob       Q3         4
# 8     Charlie       Q3         5

# %% [markdown]
# # Crosstab

# %%
data = {
    "Gender": ["M", "F", "M", "F", "F"],
    "Education": ["High school", "College", "High school", "College", "Graduate"],
    "Satisfaction": [3, 4, 5, 4, 5],
}

df = pd.DataFrame(data)

df
# Out:
#   Gender    Education  Satisfaction
# 0      M  High school             3
# 1      F      College             4
# 2      M  High school             5
# 3      F      College             4
# 4      F     Graduate             5

# %%
df_crosstab = pd.crosstab(index=[df["Gender"], df["Education"]], columns=df["Satisfaction"])

df_crosstab
# Out:
# Satisfaction        3  4  5
# Gender Education
# F      College      0  2  0
#        Graduate     0  0  1
# M      High school  1  0  1

# %%
df_crosstab = pd.crosstab(index=[df["Gender"], df["Education"]], columns=df["Satisfaction"], margins=True)

df_crosstab
# Out:
# Satisfaction        3  4  5  All
# Gender Education
# F      College      0  2  0    2
#        Graduate     0  0  1    1
# M      High school  1  0  1    2
# All                 1  2  2    5

# %%
df_crosstab = pd.crosstab(index=[df["Gender"], df["Education"]], columns=df["Satisfaction"], margins=True, margins_name="Total")

df_crosstab
# Out:
# Satisfaction        3  4  5  Total
# Gender Education
# F      College      0  2  0      2
#        Graduate     0  0  1      1
# M      High school  1  0  1      2
# Total               1  2  2      5
